# %% [markdown]
# ### Task 1: Aspect-based financial sentiment analysis
#
# Given a text instance in the financial domain (microblog message, news statement or headline) in English, detect the
# * target aspects which are mentioned in the text (from a pre-defined list of aspect classes) and,
# * predict the sentiment score for each of the mentioned targets. Sentiment scores will be defined using continuous numeric values ranged from -1(negative) to 1(positive).
#
# Systems will be evaluated with regard to aspect classification, sentiment classification and aspect-sentiment attachment. Participating systems will be evaluated with regard to precision, recall and F1-score for aspect classification approaches and regard to MSE and R Squared(R^2) metrics for sentiment prediction approaches.

# %%
import os
import re
os.environ['CUDA_VISIBLE_DEVICES'] = '2'
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from string import punctuation,digits

# %%
train_file ="data/task1_post_ABSA_train.json"
test_file ="data/task1_post_ABSA_test.json"

# %%
def load_data(filename, train = True):
    df = pd.read_json(filename)
    
    aspect_pair = dict()
    ids = []
    aspects = []
    snippets = []
    sentence_targets = []
    sentences = []
    sentiment_scores = []
    
    def getAspects(aspect):
        aspect = aspect.replace('[', '')
        aspect = aspect.replace(']', '')
        aspect = aspect.replace('\'', '')
        return aspect.split('/')
    
    for id in df:
        ids.append(id)
        sentence_targets.append(df[id]['info'][0]['target'].lower())
        sentences.append(df[id]['sentence'].lower())
        snippets.append(df[id]['info'][0]['snippets'].lower())
        
        if (train):
            
            aspects.append(getAspects((df[id]['info'][0]['aspects'].lower())))
            sentiment_scores.append(float((df[id]['info'][0]['sentiment_score'])))
                                    
    if (train):
        return sentences, snippets, sentence_targets, aspects, np.asarray(sentiment_scores)
    return ids, sentences, snippets

# %%
df = pd.read_json(train_file)
sentences, snippets, sentence_targets, aspects, sentiment_scores = load_data(train_file, True)

# %%
from scipy.interpolate import interp1d
def rescale(series,old_range,new_range):
    m = interp1d(old_range,new_range)
    return [float(m(x)) for x in series]
score = rescale(sentiment_scores,[-1,1],[0,1])
score = np.asarray(score)

# %%
df.T.sentence.apply(lambda x: len(x.split())).hist()

# %%
def remove_punctuation(s):
    list_punctuation = list(punctuation)
    for i in list_punctuation:
        s = s.replace(i,' ')
    return s
def clean_sentence(sentence):
    sentence = sentence.lower()
    #remove multiple repeat non num-aplha char !!!!!!!!!-->!
    sentence = re.sub(r'(\W)\1{2,}', r'\1', sentence) 
#     print(sentence)
    #removes alpha char repeating more than twice aaaa->aa
    sentence = re.sub(r'(\w)\1{2,}', r'\1\1', sentence)
#     print(sentence)
    #removes links
    sentence = re.sub(r'(?P<url>https?://[^\s]+)', r'', sentence)
#     print(sentence)
    # remove @usernames
    sentence = re.sub(r"\@(\w+)", "", sentence)
#     print(sentence)
    #removing stock names to see if it helps
#     sentence = re.sub(r"(?:\$|https?\://)\S+", "", sentence)
    #remove # from #tags
    sentence = sentence.replace('#','')
    sentence = sentence.replace("'s",'')
    sentence = sentence.replace("-",' ')
#     print(sentence)
    # split into tokens by white space
    tokens = sentence.split()
    # remove punctuation from each token
    tokens = [remove_punctuation(w) for w in tokens]
#     print(tokens)
    #     remove remaining tokens that are not alphabetic
#     tokens = [word for word in tokens if word.isalpha()]
#no removing non alpha words to keep stock names($ZSL)
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
#     for w in stop_words:
#         print(w)
#     print(tokens)
    # filter out short tokens
#     tokens = [word for word in tokens if len(word) > 1]
#     print(tokens)
    remove_digits = str.maketrans('', '', digits)
#     print(tokens)
    tokens = [w.translate(remove_digits) for w in tokens]
    tokens = [w.strip() for w in tokens]
    tokens = [w for w in tokens if w!=""]
#     print(tokens)
    tokens = ' '.join(tokens)
    return tokens

# %%
print('cleaning data set')
sentences = [clean_sentence(x) for x in sentences]
# Out:
# cleaning data set

# %%
sentences[:5]
# Out:
# ['slowly adding fio gotta careful one biggest winners',
#  'trx long setup macd cross',
#  'optimistic amzn fundementals charts look like poopoo quarter',
#  'grpn might selling ahead p earnings',
#  'iaci looks good weekly chart']

# %%
print('cleaning targets')
sentence_targets = [clean_sentence(x) for x in sentence_targets]
# Out:
# cleaning targets

# %%
# sentence_targets

# %%
lengths = [len(s.split()) for s in sentences]
max_length = max(lengths)
max_length
# Out:
# 19

# %%
import os
import h5py
import pprint
import pandas as pd 
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import backend as K
from bert.tokenization import FullTokenizer
import os 
import re
from tqdm import tqdm_notebook
import tqdm
sess=tf.Session()
# Out:
# /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/pakhi/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
max_seq_length=max_length
bert_path = "https://tfhub.dev/google/bert_uncased_L-12_H-768_A-12/1"

# %%
# padding dummy - doesnt pad
class PaddingInputExample(object):
    """Fake example so the num input examples is a multiple of the batch size.
  When running eval/predict on the TPU, we need to pad the number of examples
  to be a multiple of the batch size, because the TPU requires a fixed batch
  size. The alternative is to drop the last batch, which is bad because it means
  the entire output data won't be generated.
  We use this class instead of `None` because treating `None` as padding
  battches could cause silent errors.
  """


      
 
 # created bert tokenizer
def create_tokenizer_from_hub_module():
    bert_module =  hub.Module(bert_path)
    tokenization_info = bert_module(signature="tokenization_info", as_dict=True)
    vocab_file, do_lower_case = sess.run(
        [
            tokenization_info["vocab_file"],
            tokenization_info["do_lower_case"],
        ]
    )
    return FullTokenizer(vocab_file=vocab_file, do_lower_case=do_lower_case)


# creates the formaat for input for BERT
class InputExample(object):
    def __init__(self, guid, text, labels):
        self.guid = guid
        self.text = text
        self.labels = labels
        
class InputFeatures(object):
    def __init__(self, input_ids, input_mask, segment_ids, label_ids, is_real_example=True):
        self.input_ids = input_ids
        self.input_mask = input_mask
        self.segment_ids = segment_ids
        self.label_ids = label_ids,
        self.is_real_example=is_real_example  
        

def convert_single_example(tokenizer, example, max_seq_length=256):
    """Converts a single `InputExample` into a single `InputFeatures`."""

    if isinstance(example, PaddingInputExample):
        input_ids = [0] * max_seq_length
        input_mask = [0] * max_seq_length
        segment_ids = [0] * max_seq_length
        label = 0
        return input_ids, input_mask, segment_ids, label

    tokens = tokenizer.tokenize(example.text)
    if len(tokens) > max_seq_length - 2:
        tokens = tokens[0 : (max_seq_length - 2)]
    
    all_phrases = []
    all_tokens = []
    segment_ids = []
    all_tokens.append("[CLS]")
    segment_ids.append(0)
    for token in tokens:
        all_tokens.append(token)
        segment_ids.append(1)
    all_tokens.append("[SEP]")
    segment_ids.append(1)

    all_phrases.append(example.text)
    input_ids = tokenizer.convert_tokens_to_ids(all_tokens)
    

    # The mask has 1 for real tokens and 0 for padding tokens. Only real
    # tokens are attended to.
    input_mask = [1] * len(input_ids)

    # Zero-pad up to the sequence length.
    while len(input_ids) < max_seq_length:
        input_ids.append(0)
        input_mask.append(0)
        segment_ids.append(0)

    assert len(input_ids) == max_seq_length
    assert len(input_mask) == max_seq_length
    assert len(segment_ids) == max_seq_length

    return input_ids, input_mask, segment_ids, example.labels, all_phrases

def convert_examples_to_features(tokenizer, examples, max_seq_length=256):
    """Convert a set of `InputExample`s to a list of `InputFeatures`."""

    input_ids, input_masks, segment_ids, labels, all_phrases = [], [], [], [], []
    for i, example in enumerate(examples):
        input_id, input_mask, segment_id, label, phrases = convert_single_example(
            tokenizer, example, max_seq_length
        )
        input_ids.append(input_id)
        input_masks.append(input_mask)
        segment_ids.append(segment_id)
        labels.append(label)
        all_phrases.append(phrases)
    return (
        np.array(input_ids),
        np.array(input_masks),
        np.array(segment_ids),
        np.array(labels),
        np.array(all_phrases)
    )

def convert_text_to_examples(texts, labels):
    """Create InputExamples"""
    InputExamples = []
    
    for text, label in zip(texts, labels):
#         print(text, label)
        InputExamples.append(
            InputExample(guid=None, text=" ".join(text), labels=label)
        )
#         print(InputExamples)
    return InputExamples

def input_fn_builder(features, seq_length, is_training, drop_remainder):
    all_input_ids = []
    all_input_mask = []
    all_segment_ids = []
    all_label_ids = []

    for feature in features:
        all_input_ids.append(feature.input_ids)
        all_input_mask.append(feature.input_mask)
        all_segment_ids.append(feature.segment_ids)
        all_label_ids.append(feature.label_ids)

    def input_fn(params):
        batch_size = params["batch_size"]
        num_examples = len(features)

        # This is for demo purposes and does NOT scale to large data sets. We do
        # not use Dataset.from_generator() because that uses tf.py_func which is
        # not TPU compatible. The right way to load data is with TFRecordReader.
        
        d = tf.data.Dataset.from_tensor_slices({
            "input_ids":
                tf.constant(
                    all_input_ids, shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "input_mask":
                tf.constant(
                    all_input_mask,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "segment_ids":
                tf.constant(
                    all_segment_ids,
                    shape=[num_examples, seq_length],
                    dtype=tf.int32),
            "label_ids":
                tf.constant(all_label_ids, shape=[num_examples], dtype=tf.int32)
        })

        if is_training:
            d = d.repeat()
            d = d.shuffle(buffer_size=100)

        d = d.batch(batch_size=batch_size, drop_remainder=drop_remainder)
        return d

    return input_fn

# %%
tokenizer = create_tokenizer_from_hub_module()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0921 06:31:59.632857 140103382267712 deprecation_wrapper.py:119] From /home/pakhi/.local/lib/python3.6/site-packages/bert/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %%
# score

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sentences, score, test_size=0.2, random_state=42)

# %%
train_examples = convert_text_to_examples(X_train, y_train)
test_examples = convert_text_to_examples(X_test, y_test)

# %%
(train_input_ids, train_input_masks, train_segment_ids, train_labels, train_examples) = convert_examples_to_features(tokenizer, train_examples, max_seq_length=max_seq_length)
(test_input_ids, test_input_masks, test_segment_ids, test_labels, test_examples) = convert_examples_to_features(tokenizer, test_examples, max_seq_length=max_seq_length)

# %%
from tensorflow.keras import backend as K

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
class BertLayer(tf.keras.layers.Layer):
                    def __init__(self, n_fine_tune_layers, **kwargs):
                        self.n_fine_tune_layers = n_fine_tune_layers
                        self.trainable = True
                        self.output_size = 768
                        super(BertLayer, self).__init__(**kwargs)

                    def build(self, input_shape):
                        self.bert = hub.Module(
                        bert_path,
                        trainable=True,# did this in place of self.trainable
                        name="{}_module".format(self.name)
                      )

                        trainable_vars = self.bert.variables


                        trainable_vars = [var for var in trainable_vars if not "/cls/" in var.name]
                        #print("--------------------------len=",len(trainable_vars))
                        # Select how many layers to fine tune
                        trainable_vars = trainable_vars[-self.n_fine_tune_layers:]

                        # Add to trainable weights
                        for var in trainable_vars:
                            self._trainable_weights.append(var)

                        for var in self.bert.variables:
                            if var not in self._trainable_weights:
                                self._non_trainable_weights.append(var)

                        super(BertLayer, self).build(input_shape)

                    def call(self, inputs):
                        inputs = [K.cast(x, dtype="int32") for x in inputs]
                        input_ids, input_mask, segment_ids = inputs
                        bert_inputs = dict(
                          input_ids=input_ids, input_mask=input_mask, segment_ids=segment_ids
                      )
                        result = self.bert(inputs=bert_inputs, signature="tokens", as_dict=True)[
                          "pooled_output"
                      ]
                        return result

                    def compute_output_shape(self, input_shape):
                        return (input_shape[0], self.output_size)

# %%
total_epochs = 50

# %%
def sk_mse(y_true,y_pred):
     return K.mean(K.square(y_pred - y_true), axis=-1)
from sklearn.metrics import mean_squared_error as mse

for lr in [3e-4]:
    for epochs in [total_epochs]:
        for dropout in [0.3]:
            for layers in [2]: 
                sess=tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
                from tensorflow.keras.layers import Input,Dense
                #in_id=Input(shape=(max_seq_length,),)
                #in_mask=Input(shape=(max_seq_length,),)
                #in_segment=Input(shape=(max_seq_length,),)
                in_id = tf.keras.layers.Input(shape=(max_seq_length,))
                in_mask = tf.keras.layers.Input(shape=(max_seq_length,))
                in_segment = tf.keras.layers.Input(shape=(max_seq_length,))
                bert_inputs=[in_id,in_mask,in_segment]
                bert_outputs=BertLayer(n_fine_tune_layers=5)(bert_inputs)
                step=bert_outputs
                if layers>=3:
                    step=tf.keras.layers.Dense(512,activation='relu')(step)
                    if dropout!=0:
                        step=tf.keras.layers.Dropout(rate=dropout)(step)
                if layers>=2:
                    step=tf.keras.layers.Dense(256,activation='relu')(step)
                    if dropout!=0:
                        step=tf.keras.layers.Dropout(rate=dropout)(step)
                if layers>=1:    
                    step=tf.keras.layers.Dense(64,activation='relu')(step)
                    if dropout!=0:
                        step=tf.keras.layers.Dropout(rate=dropout)(step)
                        
                        
#                 model.add(Dense(y_train.shape[1], activation='softmax'))

# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# model.compile(loss='categorical_crossentropy',
#               optimizer=sgd,
#               metrics=['accuracy',])

                pred=tf.keras.layers.Dense(1,activation='sigmoid')(step)
                
#                 pred=tf.keras.layers.Dense(512,activation='relu')(step)
                model=tf.keras.Model(inputs=bert_inputs,outputs=pred)
    
                model.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.SGD(lr = lr),
                        metrics=[sk_mse])
                sess.run(tf.local_variables_initializer())
                sess.run(tf.global_variables_initializer())
                sess.run(tf.tables_initializer())
                K.set_session(sess)

           
                model.fit([train_input_ids, train_input_masks, train_segment_ids],
                        train_labels,
                        epochs=epochs,
                        batch_size=64,
                        validation_data=([test_input_ids, test_input_masks, test_segment_ids],test_labels))
                print(lr," ",epochs," ",dropout," " ,layers)
                
#                 from sklearn.metrics import f1_score,accuracy_score
#                 predict=model.predict([test_input_ids, test_input_masks, test_segment_ids])>0.5
#                 print("task=",f1_score(test_labels,predict),"  acc=",accuracy_score(test_labels,predict))
                
                
                model.save('model-{}-{}-{}-{}.h5'.format(lr,epochs,dropout,layers))
# Out:
# W0921 06:32:10.637991 140103382267712 deprecation.py:506] From /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0921 06:32:10.728289 140103382267712 deprecation.py:323] From /home/pakhi/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 540 samples, validate on 135 samples
# Epoch 1/50
# 540/540 [==============================] - 19s 36ms/sample - loss: 0.7319 - sk_mse: 0.0657 - val_loss: 0.6868 - val_sk_mse: 0.0437
# Epoch 2/50
# 540/540 [==============================] - 17s 32ms/sample - loss: 0.7199 - sk_mse: 0.0603 - val_loss: 0.6860 - val_sk_mse: 0.0433
# Epoch 3/50
# 540/540 [==============================] - 17s 31ms/sample - loss: 0.7354 - sk_mse: 0.0671 - val_loss: 0.6856 - val_sk_mse: 0.0431
# Epoch 4/50
# 540/540 [==============================] - 17s 31ms/sample - loss: 0.7192 - sk_mse: 0.0597 - val_loss: 0.6855 - val_sk_mse: 0.0430
# Epoch 5/50
# 540/540 [==============================] - 15s 28ms/sample - loss: 0.7126 - sk_mse: 0.0566 - val_loss: 0.6856 - val_sk_mse: 0.0430
# Epoch 6/50
# 540/540 [==============================] - 16s 29ms/sample - loss: 0.7164 - sk_mse: 0.0584 - val_loss: 0.6857 - val_sk_mse: 0.0431
# Epoch 7/50
# 540/540 [==============================] - 16s 30ms/sample - loss: 0.7251 - sk_mse: 0.0623 - val_loss: 0.6858 - val_sk_mse: 0.0432
# Epoch 8/50
# 540/540 [==============================] - 16s 29ms/sample - loss: 0.7189 - sk_mse: 0.0595 - val_loss: 0.6861 - val_sk_mse: 0.0433
# Epoch 9/50
# 540/540 [==============================] - 16s 30ms/sample - loss: 0.7112 - sk_mse: 0.0559 - val_loss: 0.6864 - val_sk_mse: 0.0435
# Epoch 10/50
# 540/540 [==============================] - 15s 28ms/sample - loss: 0.7110 - sk_mse: 0.0558 - val_loss: 0.6866 - val_sk_mse: 0.0435
# Epoch 11/50
# 540/540 [==============================] - 29s 54ms/sample - loss: 0.7139 - sk_mse: 0.0574 - val_loss: 0.6866 - val_sk_mse: 0.0436
# Epoch 12/50
# 540/540 [==============================] - 25s 47ms/sample - loss: 0.7115 - sk_mse: 0.0562 - val_loss: 0.6868 - val_sk_mse: 0.0437
# Epoch 13/50
# 540/540 [==============================] - 18s 33ms/sample - loss: 0.7179 - sk_mse: 0.0593 - val_loss: 0.6869 - val_sk_mse: 0.0437
# Epoch 14/50
# 540/540 [==============================] - 18s 33ms/sample - loss: 0.7055 - sk_mse: 0.0535 - val_loss: 0.6869 - val_sk_mse: 0.0437
# Epoch 15/50
# 540/540 [==============================] - 16s 29ms/sample - loss: 0.7217 - sk_mse: 0.0608 - val_loss: 0.6871 - val_sk_mse: 0.0438
# Epoch 16/50
# 540/540 [==============================] - 16s 30ms/sample - loss: 0.7162 - sk_mse: 0.0583 - val_loss: 0.6873 - val_sk_mse: 0.0439
# Epoch 17/50
# 540/540 [==============================] - 16s 30ms/sample - loss: 0.7112 - sk_mse: 0.0559 - val_loss: 0.6872 - val_sk_mse: 0.0439
# Epoch 18/50
# 540/540 [==============================] - 18s 33ms/sample - loss: 0.7135 - sk_mse: 0.0571 - val_loss: 0.6875 - val_sk_mse: 0.0440
# Epoch 19/50
# 540/540 [==============================] - 18s 34ms/sample - loss: 0.7139 - sk_mse: 0.0570 - val_loss: 0.6873 - val_sk_mse: 0.0439
# Epoch 20/50
# 540/540 [==============================] - 18s 34ms/sample - loss: 0.7067 - sk_mse: 0.0537 - val_loss: 0.6874 - val_sk_mse: 0.0440
# Epoch 21/50
# 540/540 [==============================] - 19s 36ms/sample - loss: 0.7130 - sk_mse: 0.0568 - val_loss: 0.6874 - val_sk_mse: 0.0440
# Epoch 22/50
# 540/540 [==============================] - 19s 35ms/sample - loss: 0.7023 - sk_mse: 0.0520 - val_loss: 0.6875 - val_sk_mse: 0.0440
# Epoch 23/50
# 540/540 [==============================] - 19s 35ms/sample - loss: 0.7101 - sk_mse: 0.0558 - val_loss: 0.6876 - val_sk_mse: 0.0441
# Epoch 24/50
# 540/540 [==============================] - 30s 56ms/sample - loss: 0.7055 - sk_mse: 0.0535 - val_loss: 0.6878 - val_sk_mse: 0.0441
# Epoch 25/50
# 540/540 [==============================] - 22s 41ms/sample - loss: 0.7051 - sk_mse: 0.0531 - val_loss: 0.6880 - val_sk_mse: 0.0442
# Epoch 26/50
# 540/540 [==============================] - 31s 57ms/sample - loss: 0.7136 - sk_mse: 0.0572 - val_loss: 0.6878 - val_sk_mse: 0.0441
# Epoch 27/50
# 540/540 [==============================] - 32s 60ms/sample - loss: 0.7157 - sk_mse: 0.0583 - val_loss: 0.6880 - val_sk_mse: 0.0442
# Epoch 28/50
# 540/540 [==============================] - 30s 55ms/sample - loss: 0.6979 - sk_mse: 0.0499 - val_loss: 0.6882 - val_sk_mse: 0.0443
# Epoch 29/50
# 540/540 [==============================] - 30s 56ms/sample - loss: 0.7128 - sk_mse: 0.0568 - val_loss: 0.6882 - val_sk_mse: 0.0443
# Epoch 30/50
# 540/540 [==============================] - 32s 59ms/sample - loss: 0.7115 - sk_mse: 0.0563 - val_loss: 0.6881 - val_sk_mse: 0.0443
# Epoch 31/50
# 540/540 [==============================] - 22s 41ms/sample - loss: 0.7131 - sk_mse: 0.0568 - val_loss: 0.6880 - val_sk_mse: 0.0442
# Epoch 32/50
# 540/540 [==============================] - 20s 37ms/sample - loss: 0.7015 - sk_mse: 0.0516 - val_loss: 0.6878 - val_sk_mse: 0.0441
# Epoch 33/50
# 540/540 [==============================] - 14s 27ms/sample - loss: 0.7034 - sk_mse: 0.0524 - val_loss: 0.6878 - val_sk_mse: 0.0442
# Epoch 34/50
# 540/540 [==============================] - 14s 26ms/sample - loss: 0.7044 - sk_mse: 0.0528 - val_loss: 0.6877 - val_sk_mse: 0.0441
# Epoch 35/50
# 540/540 [==============================] - 13s 25ms/sample - loss: 0.6994 - sk_mse: 0.0504 - val_loss: 0.6878 - val_sk_mse: 0.0441
# Epoch 36/50
# 540/540 [==============================] - 14s 25ms/sample - loss: 0.7084 - sk_mse: 0.0547 - val_loss: 0.6877 - val_sk_mse: 0.0441
# Epoch 37/50
# 540/540 [==============================] - 14s 25ms/sample - loss: 0.7129 - sk_mse: 0.0567 - val_loss: 0.6878 - val_sk_mse: 0.0441
# Epoch 38/50
# 540/540 [==============================] - 14s 25ms/sample - loss: 0.7017 - sk_mse: 0.0514 - val_loss: 0.6878 - val_sk_mse: 0.0441
# Epoch 39/50
# 540/540 [==============================] - 13s 25ms/sample - loss: 0.7052 - sk_mse: 0.0532 - val_loss: 0.6877 - val_sk_mse: 0.0441
# Epoch 40/50
# 540/540 [==============================] - 13s 24ms/sample - loss: 0.7071 - sk_mse: 0.0543 - val_loss: 0.6877 - val_sk_mse: 0.0441
# Epoch 41/50
# 540/540 [==============================] - 14s 25ms/sample - loss: 0.7074 - sk_mse: 0.0544 - val_loss: 0.6877 - val_sk_mse: 0.0441
# Epoch 42/50
# 540/540 [==============================] - 14s 26ms/sample - loss: 0.7128 - sk_mse: 0.0570 - val_loss: 0.6876 - val_sk_mse: 0.0441
# Epoch 43/50
# 540/540 [==============================] - 13s 24ms/sample - loss: 0.6993 - sk_mse: 0.0506 - val_loss: 0.6877 - val_sk_mse: 0.0441
# Epoch 44/50
# 540/540 [==============================] - 13s 24ms/sample - loss: 0.7071 - sk_mse: 0.0541 - val_loss: 0.6875 - val_sk_mse: 0.0440
# Epoch 45/50
# 540/540 [==============================] - 14s 25ms/sample - loss: 0.7064 - sk_mse: 0.0540 - val_loss: 0.6875 - val_sk_mse: 0.0440
# Epoch 46/50
# 540/540 [==============================] - 12s 23ms/sample - loss: 0.7002 - sk_mse: 0.0508 - val_loss: 0.6874 - val_sk_mse: 0.0440
# Epoch 47/50
# 540/540 [==============================] - 12s 23ms/sample - loss: 0.7046 - sk_mse: 0.0530 - val_loss: 0.6873 - val_sk_mse: 0.0439
# Epoch 48/50
# 540/540 [==============================] - 14s 26ms/sample - loss: 0.6999 - sk_mse: 0.0508 - val_loss: 0.6873 - val_sk_mse: 0.0439
# Epoch 49/50
# 540/540 [==============================] - 14s 25ms/sample - loss: 0.7075 - sk_mse: 0.0545 - val_loss: 0.6873 - val_sk_mse: 0.0439
# Epoch 50/50
# 540/540 [==============================] - 13s 24ms/sample - loss: 0.7015 - sk_mse: 0.0515 - val_loss: 0.6873 - val_sk_mse: 0.0439
# 0.0003   50   0.3   2

# %%
def sk_mse(y_true,y_pred):
     return K.mean(K.square(y_pred - y_true), axis=-1)
from sklearn.metrics import mean_squared_error as mse

for lr in [3e-4]:
    for epochs in [total_epochs]:
        for dropout in [0.3]:
            for layers in [3]: 
                sess=tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
                from tensorflow.keras.layers import Input,Dense
                #in_id=Input(shape=(max_seq_length,),)
                #in_mask=Input(shape=(max_seq_length,),)
                #in_segment=Input(shape=(max_seq_length,),)
                in_id = tf.keras.layers.Input(shape=(max_seq_length,))
                in_mask = tf.keras.layers.Input(shape=(max_seq_length,))
                in_segment = tf.keras.layers.Input(shape=(max_seq_length,))
                bert_inputs=[in_id,in_mask,in_segment]
                bert_outputs=BertLayer(n_fine_tune_layers=10)(bert_inputs)
                step=bert_outputs
                if layers>=3:
                    step=tf.keras.layers.Dense(512,activation='relu')(step)
                    if dropout!=0:
                        step=tf.keras.layers.Dropout(rate=dropout)(step)
                if layers>=2:
                    step=tf.keras.layers.Dense(256,activation='relu')(step)
                    if dropout!=0:
                        step=tf.keras.layers.Dropout(rate=dropout)(step)
                if layers>=1:    
                    step=tf.keras.layers.Dense(64,activation='relu')(step)
                    if dropout!=0:
                        step=tf.keras.layers.Dropout(rate=dropout)(step)
                        
                        
#                 model.add(Dense(y_train.shape[1], activation='softmax'))

# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# model.compile(loss='categorical_crossentropy',
#               optimizer=sgd,
#               metrics=['accuracy',])

                pred=tf.keras.layers.Dense(1,activation='sigmoid')(step)
                
#                 pred=tf.keras.layers.Dense(512,activation='relu')(step)
                model=tf.keras.Model(inputs=bert_inputs,outputs=pred)
    
                model.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(),
                        metrics=[sk_mse])
                sess.run(tf.local_variables_initializer())
                sess.run(tf.global_variables_initializer())
                sess.run(tf.tables_initializer())
                K.set_session(sess)

           
                model.fit([train_input_ids, train_input_masks, train_segment_ids],
                        train_labels,
                        epochs=epochs,
                        batch_size=64,
                        validation_data=([test_input_ids, test_input_masks, test_segment_ids],test_labels))
                print(lr," ",epochs," ",dropout," " ,layers)
                
#                 from sklearn.metrics import f1_score,accuracy_score
#                 predict=model.predict([test_input_ids, test_input_masks, test_segment_ids])>0.5
#                 print("task=",f1_score(test_labels,predict),"  acc=",accuracy_score(test_labels,predict))
                
                
                model.save('model-{}-{}-{}-{}.h5'.format(lr,epochs,dropout,layers))

# %%
from keras.models import load_model
model.load_weights("model-0.0003-50-0.3-2.h5")

# %%
# sentences, snippets, sentence_targets = load_data(test_file,False)

# %%
import tensorflow as tf
from keras import backend as K

with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    print(x.eval())
# Out:
# [0.04228542 0.04635481 0.04639622 0.04229137 0.0419168  0.08598778
#  0.05294004 0.04566521 0.05538781 0.04919351 0.05847561 0.08086222
#  0.04201136 0.04231504 0.07805026 0.04793698 0.04709451 0.04434207
#  0.05671643 0.06963301 0.0447852  0.04693359 0.06271897 0.04186552
#  0.07006823 0.08654392 0.04632385 0.05089989 0.06610586 0.07212201
#  0.05023433 0.04173227 0.04693127 0.04175879 0.04446321 0.07106253
#  0.05510156 0.0447852  0.04193075 0.0442617  0.05080562 0.04205786
#  0.04177163 0.04626166 0.04174399 0.04192484 0.04172815 0.05371148
#  0.06341856 0.04280535 0.06103785 0.05276686 0.04256677 0.08942407
#  0.04173762 0.04176524 0.08477106 0.07470819 0.0430429  0.04373793
#  0.04173628 0.0418129  0.06306099 0.04719155 0.06942317 0.04174575
#  0.04193601 0.05030504 0.05649036 0.05343602 0.04174253 0.04204969
#  0.04896932 0.04356697 0.05262467 0.0485943  0.04220891 0.04194627
#  0.04602109 0.04564696 0.04613045 0.07988592 0.04738835 0.05239591
#  0.04766217 0.07470819 0.04177954 0.04225017]

# %%
ss= sk_mse(y_test, preds)

# %%
import numpy
x = (K.mean(K.square(preds - y_test), axis=-1))

# %%
# # train_examples = convert_text_to_examples(X_train,y_train)
# test_examples = convert_text_to_examples(sentences, sentence_targets)
# # (train_input_ids, train_input_masks, train_segment_ids, train_labels, train_examples) = convert_examples_to_features(tokenizer, train_examples, max_seq_length=max_seq_length)
# (test_input_ids, test_input_masks, test_segment_ids, test_labels, test_examples) = convert_examples_to_features(tokenizer, test_examples, max_seq_length=max_seq_length)
# # train_examples = [str(tr).replace(" ","-").replace("--"," ").replace("-","") for tr in train_examples]
# # test_examples = [str(tr).replace(" ","-").replace("--"," ").replace("-","") for tr in test_examples]

preds = model.predict([test_input_ids, 
                       test_input_masks, 
                      test_segment_ids])

# %%
pred_val = [x[0] for x in preds]
pred_val = rescale(pred_val,[-1,1],[0,1])

# %%
y_test[:10]
# Out:
# array([0.356 , 0.607 , 0.209 , 0.6435, 0.6815, 0.7595, 0.2015, 0.3445,
#        0.6695, 0.6825])

# %%
preds.shape
# Out:
# (88, 1)

# %%
X_test
# Out:
# ['berkshire discloses unit ties iran opens probe',
#  'kraft heinz merger came together speedy weeks',
#  'us dollar wipes sales gains sabmiller',
#  'shire says internal synergy goals baxalta deal higher',
#  'greene king third quarter sales boosted festive season',
#  'astrazeneca chases acerta secure next cancer drug winner',
#  'ftse drops pct glencore metals price fears',
#  'kingfisher takeover mr bricolage could hit brick wall',
#  'uk housing market steadies brexit dip persimmon says',
#  'whitbread buys stake pure food chain',
#  'companiestesco bad start xmas â€“ kantar',
#  'british american tobacco drops sues pwc pollution scandal',
#  'ab inbev looks win sabmiller investors',
#  'retail giant kingfisher reports olid start year',
#  'ftse falls month low greek debt concerns easyjet skids',
#  'uk ftse worst day far bg prudential fall',
#  'aviva m g suspend property funds investors panic',
#  'rio tinto ceo says iron ore market equilibrium',
#  'citigroup sell onemain springleaf billion',
#  'update stifel buy former lehman brokerage barclays',
#  'royal dutch shell profit rises dividend',
#  'ingenious hsbc ubs coutts sued tax avoidance clients',
#  'slump weir leads ftse record high',
#  'johnson matthey revs clean air drive',
#  'rolls royce wins billion order emirates airline',
#  'britain ftse bounces back mondi barratt lead',
#  'london open taylor wimpey ashtead drive markets higher barclays falls',
#  'wpp world largest ad agency reports strong growth',
#  'hammerson jv partner secure ownership ireland dundrum quick facts',
#  'aviva fined million u k regulator fee failings',
#  'aviva promises higher dividends boost flagging share price',
#  'tesco criticised disgraceful advert showing domestic worker slapped',
#  'glaxo viiv healthcare signs china manufacturing deal desano',
#  'morrisons debenhams surprise city christmas bounce back',
#  'entertainment one dispels itv takeover rumours',
#  'aviva friends life top forecasts ahead billion pound merger',
#  'tesco asda sales fall march discounters continues kantar',
#  'royal dutch shell buy bg group nearly billion',
#  'glencore cuts budget plans divest lonmin',
#  'dbs julius baer emerge potential bidders barclays asia wealth unit',
#  'news feedftse movers lse surges ice says mulling offer ashtead barclays tank',
#  'britain ftse gains land securities dividend hike',
#  'update sabmiller rejects ab inbev bln takeover approach',
#  'astrazeneca teams daiichi sankyo sell movantik us',
#  'borealis infrastructure putting together new severn trent bid',
#  'glaxosmithkline set complete billion novartis asset swap next week',
#  'update barclays expects gain settling lehman bros trustee',
#  'l g completes uk largest medically underwritten bulk pension risk deal',
#  'kraft cadbury britvic total recall pulling product affects profit',
#  'sab chairman digs board divided inbev offer',
#  'spain caixabank launches new takeover bid banco bpi',
#  'fda approves nps drug move validating shire takeover deal',
#  'royal mail share price rallies amid positive broker comments',
#  'hargreaves lansdown share price falls costs mount although pensions',
#  'royal mail chairman donald brydon set step',
#  'shire buy nps billion boost rare disease drugs',
#  'update pricey beers lift sabmiller quarterly underlying sales',
#  'tesco share price steady analysts weigh results',
#  'astrazeneca patent asthma drug invalidated us court',
#  'ab inbev approaches sabmiller explore bn tie',
#  'marketsbp promotes upstream boss deputy ceo',
#  'germanwings disaster affect image budget air travel easyjet',
#  'astrazeneca explores potential deal acerta cancer drug',
#  'barclays sells benchmark indices unit bloomberg',
#  'stanchart rbs struggle bank england stress tests',
#  'saudi aramco shell plan break motiva divide assets',
#  'crh concrete bid holcim lafarge assets',
#  'arm holdings plc domino pizza group plc asos plc must growth stocks',
#  'barclays poaches new chief operating officer paul compton jp morgan chase',
#  'bg group still happy shell billion offer',
#  'oil majors like royal dutch shell chevron bp fail find reserves counter',
#  'rbs chairman admits surprise size regulatory penalties',
#  'itv pursue takeover canada entertainment one bloomberg',
#  'brief legal general retirement business books billion stg h sales',
#  'companieshome retail trims gains considered in play',
#  'glencore chief blames rivals overproduction share price fall',
#  'kingfisher share price slides cost implement new strategy',
#  'companies thetrainline com announces arrival london ipo',
#  'millercoors delivers underlying net income growth',
#  'insurer old mutual picks standard bank hemphill new ceo',
#  'anheuser busch inbev increases offer rival sabmiller',
#  'retailers kingfisher sports direct rise britain share index',
#  'companiesfresnillo shares jump silver price breaks',
#  'rolls royce ensure compliance petrobras bribery report',
#  'aberdeen posts h outflows says conditions remain challenging',
#  'tesco share price jumps q sales top estimates',
#  'morrisons faces festive sales test',
#  'uk winners losers aviva friends life lead ftse gainers',
#  'glencore sees tripoli based noc sole legal seller libyan oil',
#  'intercontinental hotels first quarter global room revenue lags estimates',
#  'bunzl lifts dividend acquisitions continue boost profits',
#  'insurers admiral blows hot cold aviva soars pre friends life merger',
#  'standard chartered rbs escape capital raising stress test',
#  'zurich insurance considering offer uk rival rsa insurance',
#  'shell billion bg deal meets shareholder skepticism',
#  'copper market may get style supply shock glencore closures',
#  'london stock exchange shareholders approve merger deutsche bã¶rse',
#  'sophos aims raise m london ipo',
#  'london stock exchange seals â£ billion merger germany deutsche bã¶rse',
#  'barclays poised replace sir mike rake heads exit',
#  'priceline stock jumps new high year barclays upgrade',
#  'update pearson expects grow year solid end',
#  'tesco closes new chairman dixons carphone john allan frame',
#  'dixons carphone profit boost strong sales',
#  'tesco share price tumbles negative broker note',
#  'ge sell majority stake bank bph core bank alior bank',
#  'peroni grolsch put sale ab inbev plans acquisition sabmiller',
#  'ocwen reaches settlement california regulator',
#  'irish said chasing standard chartered rbs brexit vote nears']

# %%
y_test
# Out:
# array([0.356 , 0.607 , 0.209 , 0.6435, 0.6815, 0.7595, 0.2015, 0.3445,
#        0.6695, 0.6825, 0.198 , 0.2815, 0.638 , 0.684 , 0.293 , 0.1745,
#        0.0965, 0.5   , 0.6415, 0.582 , 0.825 , 0.376 , 0.0865, 0.612 ,
#        0.8885, 0.779 , 0.757 , 0.7775, 0.7135, 0.1625, 0.6405, 0.251 ,
#        0.642 , 0.7865, 0.569 , 0.695 , 0.301 , 0.6295, 0.343 , 0.655 ,
#        0.613 , 0.7745, 0.586 , 0.682 , 0.607 , 0.5945, 0.5995, 0.625 ,
#        0.421 , 0.508 , 0.5925, 0.666 , 0.795 , 0.243 , 0.313 , 0.6175,
#        0.7145, 0.526 , 0.172 , 0.6185, 0.533 , 0.477 , 0.686 , 0.6405,
#        0.131 , 0.429 , 0.641 , 0.5   , 0.454 , 0.6175, 0.299 , 0.3335,
#        0.5995, 0.626 , 0.5675, 0.3495, 0.107 , 0.6225, 0.7475, 0.5125,
#        0.62  , 0.7295, 0.937 , 0.4625, 0.318 , 0.8595, 0.4435, 0.758 ,
#        0.5185, 0.3355, 0.7005, 0.5265, 0.6675, 0.625 , 0.3275, 0.2145,
#        0.703 , 0.607 , 0.6635, 0.5385, 0.9235, 0.723 , 0.5645, 0.739 ,
#        0.1105, 0.6065, 0.7755, 0.5855, 0.564 ])

# %%
preds
# Out:
# array([[0.5893113 ],
#        [0.6145039 ],
#        [0.5230806 ],
#        [0.56306386],
#        [0.54047114],
#        [0.64143586],
#        [0.6093089 ],
#        [0.6004259 ],
#        [0.5357079 ],
#        [0.6039903 ],
#        [0.60341454],
#        [0.5169948 ],
#        [0.5572565 ],
#        [0.5291268 ],
#        [0.57132906],
#        [0.5365583 ],
#        [0.34788162],
#        [0.51631945],
#        [0.58267576],
#        [0.561509  ],
#        [0.5421865 ],
#        [0.53402257],
#        [0.5311986 ],
#        [0.51927257],
#        [0.26019973],
#        [0.63256836],
#        [0.56974584],
#        [0.5873601 ],
#        [0.5836445 ],
#        [0.57729363],
#        [0.59763235],
#        [0.53369987],
#        [0.5459679 ],
#        [0.55213094],
#        [0.5272893 ],
#        [0.5981059 ],
#        [0.57120275],
#        [0.5421865 ],
#        [0.54254436],
#        [0.5999911 ],
#        [0.6611622 ],
#        [0.6079808 ],
#        [0.5244283 ],
#        [0.6314275 ],
#        [0.6043837 ],
#        [0.52255017],
#        [0.5557072 ],
#        [0.52855897],
#        [0.61768913],
#        [0.4422078 ],
#        [0.63672334],
#        [0.5883324 ],
#        [0.52481306],
#        [0.52707064],
#        [0.47010118],
#        [0.55665135],
#        [0.5523325 ],
#        [0.5779615 ],
#        [0.61500305],
#        [0.5813176 ],
#        [0.5579846 ],
#        [0.54223573],
#        [0.63624495],
#        [0.6121139 ],
#        [0.55180764],
#        [0.52852494],
#        [0.61355436],
#        [0.59386086],
#        [0.58905065],
#        [0.56436354],
#        [0.5791217 ],
#        [0.49161112],
#        [0.5857859 ],
#        [0.54217196],
#        [0.57997894],
#        [0.5450471 ],
#        [0.5913487 ],
#        [0.5786342 ],
#        [0.5407473 ],
#        [0.5365417 ],
#        [0.5749064 ],
#        [0.52999115],
#        [0.6004573 ],
#        [0.56543976],
#        [0.6116134 ],
#        [0.5779615 ],
#        [0.54400826],
#        [0.545695  ],
#        [0.55649346],
#        [0.45424074],
#        [0.5622163 ],
#        [0.5506071 ],
#        [0.50676405],
#        [0.49673766],
#        [0.52704084],
#        [0.5901406 ],
#        [0.5734443 ],
#        [0.51847225],
#        [0.5734443 ],
#        [0.56927836],
#        [0.60794055],
#        [0.29535317],
#        [0.5918286 ],
#        [0.52474713],
#        [0.5779615 ],
#        [0.52597076],
#        [0.5878026 ],
#        [0.63816524],
#        [0.56878126]], dtype=float32)

# %%
result = {'results':[]}

# %%
for s_id,s_sn,s_score in zip(sentences,snippets,score):
    result['results'].append({'id':s_id,'snippet':s_sn,'sentiment_scores':str(s_score)})

# %%
result = {'results':[]}

for s_id,s_sn,s_score in zip(sentences,snippets,pred_val):
    result['results'].append({'id':s_id,'snippet':s_sn,'sentiment_scores':str(s_score)})

# %%
result
# Out:
# {'results': [{'id': '0_Cuadrilla',
#    'snippet': 'cuadrilla files to delay application to frack in lancashire',
#    'sentiment_scores': '0.313'},
#   {'id': '1001_Sainsbury',
#    'snippet': 'sainsbury chief warns of squeeze on high street retailers',
#    'sentiment_scores': '0.38'},
#   {'id': '1006_Barclays',
#    'snippet': 'barclays fined for anti-money-laundering failings',
#    'sentiment_scores': '0.4195'},
#   {'id': '1007_Barclays',
#    'snippet': "update 3-barclays fined for lax crime checks in 'deal of century'",
#    'sentiment_scores': '0.5685'},
#   {'id': '1014_GSK',
#    'snippet': 'gsk aims to file up to 20 new drugs for approval by 2020',
#    'sentiment_scores': '0.852'},
#   {'id': '1031_National Grid',
#    'snippet': 'companiesnational grid lines up sale of gas business',
#    'sentiment_scores': '0.723'},
#   {'id': '1034_British American Tobacco',
#    'snippet': 'british american tobacco accused of bribing senior politicians to sabotage ...',
#    'sentiment_scores': '0.5680000000000001'},
#   {'id': '1035_MillerCoors',
#    'snippet': 'update 2-ab inbev launches sab bid, to sell millercoors stake',
#    'sentiment_scores': '0.6065'},
#   {'id': '1039_AstraZeneca',
#    'snippet': 'astrazeneca shares climb 3% as drug maker ups profits forecasts',
#    'sentiment_scores': '0.6945'},
#   {'id': '103_Hammerson',
#    'snippet': "landlord hammerson's nav rises on increased leasing activity",
#    'sentiment_scores': '0.825'},
#   {'id': '1050_BAE Systems',
#    'snippet': 'bae systems cuts earnings target for 2015 and 370 jobs',
#    'sentiment_scores': '0.5975'},
#   {'id': '1055_Barclays',
#    'snippet': 'barclays settles with us investors over libor manipulation',
#    'sentiment_scores': '0.5595'},
#   {'id': '1068_Bunzl',
#    'snippet': 'bunzl backs 2015 view, buys more businesses',
#    'sentiment_scores': '0.621'},
#   {'id': '1075_L&G',
#    'snippet': 'l&g strikes â£230m bulk annuity deal',
#    'sentiment_scores': '0.6645'},
#   {'id': '1082_Bloomberg',
#    'snippet': "bloomberg buys barclays' benchmarking business",
#    'sentiment_scores': '0.40249999999999997'},
#   {'id': '1083_Barclays',
#    'snippet': 'barclays in $13.75 million us settlement over mutual funds',
#    'sentiment_scores': '0.666'},
#   {'id': '1088_Tesco',
#    'snippet': 'tesco uk personnel director quits supermarket',
#    'sentiment_scores': '0.5855'},
#   {'id': '109_Severn Trent',
#    'snippet': 'companies severn trent expects costs hit from inflation',
#    'sentiment_scores': '0.4435'},
#   {'id': '10_EasyJet',
#    'snippet': 'update 2-easyjet sees better first half on lower fuel bill',
#    'sentiment_scores': '0.3215'},
#   {'id': '1104_BHP Billiton',
#    'snippet': 'bhp billiton to lower copper production costs',
#    'sentiment_scores': '0.6174999999999999'},
#   {'id': '1115_AstraZeneca',
#    'snippet': 'astrazeneca in talks to buy cancer drug developer acerta pharma',
#    'sentiment_scores': '0.6475'},
#   {'id': '1123_Lloyds',
#    'snippet': 'osborne extends lloyds sell-off plan',
#    'sentiment_scores': '0.6455'},
#   {'id': '1126_Barclays',
#    'snippet': "industry newsbarclays to 'cut investment bank staff by another 20%'",
#    'sentiment_scores': '0.6225'},
#   {'id': '1127_RBS',
#    'snippet': 'rbs investment bank to return to profit after overhaul, ceo says',
#    'sentiment_scores': '0.56'},
#   {'id': '1138_Barclays',
#    'snippet': 'che banca! ceo says barclays buy to lift profit from 2016-17',
#    'sentiment_scores': '0.8594999999999999'},
#   {'id': '113_BHP',
#    'snippet': "bhp's iron ore outlook holds little cheer for small miners",
#    'sentiment_scores': '0.641'},
#   {'id': '1163_Morrisons',
#    'snippet': 'early victory for new ceo as morrisons beats forecasts',
#    'sentiment_scores': '0.9875'},
#   {'id': '1173_BP',
#    'snippet': 'bp to slash 4000 jobs globally as oil prices drop',
#    'sentiment_scores': '0.3695'},
#   {'id': '1175_Morrisons',
#    'snippet': 'uk supermarket group morrisons cuts fresh food prices',
#    'sentiment_scores': '0.237'},
#   {'id': '117_AO World',
#    'snippet': 'ao world shares tumble on profit warning',
#    'sentiment_scores': '0.5105'},
#   {'id': '1187_Direct Line',
#    'snippet': 'direct line expects claims of â£110-140 million from three storms',
#    'sentiment_scores': '0.08650000000000002'},
#   {'id': '1188_RBS',
#    'snippet': 'rbs shares drop after surprise pension charge cuts capital',
#    'sentiment_scores': '0.7005'},
#   {'id': '119_StanLife',
#    'snippet': 'stanlife leads ftse after strong earnings',
#    'sentiment_scores': '0.761'},
#   {'id': '1214_Diageo',
#    'snippet': 'diageo offloads major wine interests',
#    'sentiment_scores': '0.5945'},
#   {'id': '1235_Glencore',
#    'snippet': 'update 1-lpc-glencore launches refinancing of us$8.45bn loan',
#    'sentiment_scores': '0.07300000000000001'},
#   {'id': '1238_Glencore',
#    'snippet': 'lpc-glencore launches refinancing of $8.45billion loan',
#    'sentiment_scores': '0.44'},
#   {'id': '124_RBS',
#    'snippet': 'rbs breaks with past by tearing investment bank apart',
#    'sentiment_scores': '0.7855'},
#   {'id': '1254_Smith & Nephew',
#    'snippet': 'smith & nephew 2015 trading profit beats expectations',
#    'sentiment_scores': '0.5505'},
#   {'id': '1263_BT Group',
#    'snippet': "bt group's third quarter revenues rise as restructure unveiled",
#    'sentiment_scores': '0.5345'},
#   {'id': '1266_Johnston Press',
#    'snippet': "indy future in doubt as johnston press lines up deal for 'i'",
#    'sentiment_scores': '0.34299999999999997'},
#   {'id': '1269_BP',
#    'snippet': 'bp shares tumble after $2.2bn fourth-quarter loss',
#    'sentiment_scores': '0.524'},
#   {'id': '126_Randgold Resources',
#    'snippet': 'randgold resources q4 profit decreases - quick facts',
#    'sentiment_scores': '0.251'},
#   {'id': '1271_BHP Billiton',
#    'snippet': 'bhp billiton says no settlement yet on brazil dam disaster',
#    'sentiment_scores': '0.299'},
#   {'id': '1273_Hargreaves Landown',
#    'snippet': 'hargreaves landown slides on trading update',
#    'sentiment_scores': '0.321'},
#   {'id': '1280_AstraZeneca',
#    'snippet': 'astrazeneca says new lung cancer pill tagrisso approved by eu',
#    'sentiment_scores': '0.6819999999999999'},
#   {'id': '1285_Berkshire Hathaway',
#    'snippet': "warren buffett's berkshire hathaway quarterly profit jumps almost one third",
#    'sentiment_scores': '0.5645'},
#   {'id': '1286_Genel',
#    'snippet': "genel shares plunge after tony hayward's oil explorer cuts crude reserves at core field",
#    'sentiment_scores': '0.7475'},
#   {'id': '1300_AstraZeneca',
#    'snippet': 'astrazeneca agrees licensing deal for plendil in china',
#    'sentiment_scores': '0.5445'},
#   {'id': '1301_Glencore',
#    'snippet': 'glencore posts 5.7 pct fall in q4 copper output',
#    'sentiment_scores': '0.203'},
#   {'id': '1310_Glencore',
#    'snippet': 'glencore to refinance its short-term debt early, shares rise',
#    'sentiment_scores': '0.71'},
#   {'id': '131_Glaxo',
#    'snippet': 'glaxo sees hope for respiratory drugs as earnings beat estimates',
#    'sentiment_scores': '0.443'},
#   {'id': '1321_Weir Group',
#    'snippet': 'industry newsrevenue, earnings take a tumble at weir group',
#    'sentiment_scores': '0.9685'},
#   {'id': '1337_AstraZeneca',
#    'snippet': 'companiesastrazeneca shares hit as 2016 revenue forecast to fall',
#    'sentiment_scores': '0.6825'},
#   {'id': '1338_Lloyds Banking Group',
#    'snippet': 'lloyds banking group reports 7% dip in annual profits',
#    'sentiment_scores': '0.5695'},
#   {'id': '1340_Berkshire',
#    'snippet': "update 3-buffett's berkshire raises oil bet with kinder morgan stake",
#    'sentiment_scores': '0.658'},
#   {'id': '1344_Associated British Foods',
#    'snippet': 'associated british foods raises guidance as sterling wilts',
#    'sentiment_scores': '0.16249999999999998'},
#   {'id': '1347_Glencore',
#    'snippet': 'companiesglencore shares hit 3-month high after refinancing key credit line',
#    'sentiment_scores': '0.172'},
#   {'id': '1348_JP Morgan Chase',
#    'snippet': 'companiescoutts raids jpmorgan chase for new ceo',
#    'sentiment_scores': '0.4625'},
#   {'id': '1355_Admiral and Schroders',
#    'snippet': 'admiral and schroders lift ftse with profits surge',
#    'sentiment_scores': '0.7565'},
#   {'id': '1361_Admiral',
#    'snippet': "britain's ftse buoyed by admiral, building sector gains",
#    'sentiment_scores': '0.572'},
#   {'id': '1363_Legal & General',
#    'snippet': "legal & general's capital update outweighs profit rise",
#    'sentiment_scores': '0.626'},
#   {'id': '1369_Kingfisher',
#    'snippet': "britain's ftse advances as investors cheer kingfisher results",
#    'sentiment_scores': '0.6935'},
#   {'id': '1374_BP',
#    'snippet': 'bp ends 27-year sponsorship of tate as falling oil price takes toll',
#    'sentiment_scores': '0.8275'},
#   {'id': '1393_Shell',
#    'snippet': "shell ceo van beurden's remuneration fell in 2015",
#    'sentiment_scores': '0.4095'},
#   {'id': '1397_HSBC',
#    'snippet': "hsbc money laundering report's release delayed amid us appeal",
#    'sentiment_scores': '0.642'},
#   {'id': '1399_Rio Tinto',
#    'snippet': "standout performer' js jacques picked to lead rio tinto",
#    'sentiment_scores': '0.5805'},
#   {'id': '1401_Barclays',
#    'snippet': 'barclays reports 8% fall in annual profits',
#    'sentiment_scores': '0.758'},
#   {'id': '1406_Metro Bank',
#    'snippet': 'companiesmetro bank raises â£400m ahead of london listing',
#    'sentiment_scores': '0.768'},
#   {'id': '1411_Sports Direct',
#    'snippet': 'sports direct boss mike ashley summoned to westminster for questioning over the treatment of workers',
#    'sentiment_scores': '0.3735'},
#   {'id': '1413_Aggreko',
#    'snippet': 'aggreko says first half profits will be lower as the oil price rout claims its latest victim',
#    'sentiment_scores': '0.8205'},
#   {'id': '141_Berkshire Hathaway',
#    'snippet': "berkshire hathaway's 4q profit declines 17 percent",
#    'sentiment_scores': '0.757'},
#   {'id': '144_Bunzl',
#    'snippet': 'bunzl delivers small profit increase for 2014',
#    'sentiment_scores': '0.632'},
#   {'id': '1452_BP',
#    'snippet': 'bp sees q1 earnings slide as low oil prices take their toll',
#    'sentiment_scores': '0.6950000000000001'},
#   {'id': '1457_BP',
#    'snippet': 'bp reports $583 million loss in first quarter',
#    'sentiment_scores': '0.6415'},
#   {'id': '1459_AB InBev',
#    'snippet': 'ab inbev offers to sell some sabmiller brands',
#    'sentiment_scores': '0.772'},
#   {'id': '1464_AstraZeneca',
#    'snippet': 'astrazeneca to cut costs but stays silent on m&a talk',
#    'sentiment_scores': '0.2815'},
#   {'id': '1466_Barclays',
#    'snippet': 'barclays in talks with anacap to sell french consumer operations',
#    'sentiment_scores': '0.1745'},
#   {'id': '1479_Kraft Heinz',
#    'snippet': 'the latest: buffett says cuts will pay off at kraft heinz',
#    'sentiment_scores': '0.421'},
#   {'id': '1483_Shoeders',
#    'snippet': 'schroders assets hit record in q1, buoyed by institutional inflows',
#    'sentiment_scores': '0.607'},
#   {'id': '1489_Barclays',
#    'snippet': 'former barclays traders stand trial in libor case',
#    'sentiment_scores': '0.6819999999999999'},
#   {'id': '148_Standard Life',
#    'snippet': 'standard life impresses as fee-based products offset annuities slump',
#    'sentiment_scores': '0.392'},
#   {'id': '1494_Sky',
#    'snippet': "britain's ftse slips from 2016 high as sky falls",
#    'sentiment_scores': '0.5625'},
#   {'id': '149_Reed Elsevier',
#    'snippet': 'reed elsevier shares cool after profit dip',
#    'sentiment_scores': '0.34450000000000003'},
#   {'id': '1520_Lloyds',
#    'snippet': 'retail focus helps to shield lloyds from banking chill',
#    'sentiment_scores': '0.246'},
#   {'id': '1538_Centrica',
#    'snippet': 'companiescentrica shares drop 7% amid capital raise',
#    'sentiment_scores': '0.5265'},
#   {'id': '1539_United Utilities',
#    'snippet': 'united utilities fy profit up 3.5%; to boost capex',
#    'sentiment_scores': '0.6805'},
#   {'id': '1542_Compass',
#    'snippet': 'companiescompass serves up half year profit rise',
#    'sentiment_scores': '0.6895'},
#   {'id': '1547_SABMiller',
#    'snippet': 'currency causes full-year headaches for sabmiller',
#    'sentiment_scores': '0.474'},
#   {'id': '1572_Exxon',
#    'snippet': 'exxon beaumont cdu overhaul to be slowed by accident: sources',
#    'sentiment_scores': '0.747'},
#   {'id': '1574_G4S',
#    'snippet': "companiesg4s claims 'positive' start to the year",
#    'sentiment_scores': '0.7215'},
#   {'id': '1594_Rio Tinto',
#    'snippet': 'rio tinto announces long-delayed expansion of mongolia mine',
#    'sentiment_scores': '0.5125'},
#   {'id': '1603_Apple',
#    'snippet': "warren buffett's berkshire hathaway buys stake in apple",
#    'sentiment_scores': '0.5715'},
#   {'id': '1614_Royal Mail',
#    'snippet': 'ofcom says will not impose new price controls on royal mail',
#    'sentiment_scores': '0.5'},
#   {'id': '0_Cuadrilla',
#    'snippet': 'cuadrilla files to delay application to frack in lancashire',
#    'sentiment_scores': '0.7946556508541107'},
#   {'id': '1001_Sainsbury',
#    'snippet': 'sainsbury chief warns of squeeze on high street retailers',
#    'sentiment_scores': '0.8072519600391388'},
#   {'id': '1006_Barclays',
#    'snippet': 'barclays fined for anti-money-laundering failings',
#    'sentiment_scores': '0.7615402936935425'},
#   {'id': '1007_Barclays',
#    'snippet': "update 3-barclays fined for lax crime checks in 'deal of century'",
#    'sentiment_scores': '0.7815319299697876'},
#   {'id': '1014_GSK',
#    'snippet': 'gsk aims to file up to 20 new drugs for approval by 2020',
#    'sentiment_scores': '0.7702355682849884'},
#   {'id': '1031_National Grid',
#    'snippet': 'companiesnational grid lines up sale of gas business',
#    'sentiment_scores': '0.8207179307937622'},
#   {'id': '1034_British American Tobacco',
#    'snippet': 'british american tobacco accused of bribing senior politicians to sabotage ...',
#    'sentiment_scores': '0.804654449224472'},
#   {'id': '1035_MillerCoors',
#    'snippet': 'update 2-ab inbev launches sab bid, to sell millercoors stake',
#    'sentiment_scores': '0.800212949514389'},
#   {'id': '1039_AstraZeneca',
#    'snippet': 'astrazeneca shares climb 3% as drug maker ups profits forecasts',
#    'sentiment_scores': '0.7678539454936981'},
#   {'id': '103_Hammerson',
#    'snippet': "landlord hammerson's nav rises on increased leasing activity",
#    'sentiment_scores': '0.8019951581954956'},
#   {'id': '1050_BAE Systems',
#    'snippet': 'bae systems cuts earnings target for 2015 and 370 jobs',
#    'sentiment_scores': '0.8017072677612305'},
#   {'id': '1055_Barclays',
#    'snippet': 'barclays settles with us investors over libor manipulation',
#    'sentiment_scores': '0.7584973871707916'},
#   {'id': '1068_Bunzl',
#    'snippet': 'bunzl backs 2015 view, buys more businesses',
#    'sentiment_scores': '0.7786282598972321'},
#   {'id': '1075_L&G',
#    'snippet': 'l&g strikes â£230m bulk annuity deal',
#    'sentiment_scores': '0.7645634114742279'},
#   {'id': '1082_Bloomberg',
#    'snippet': "bloomberg buys barclays' benchmarking business",
#    'sentiment_scores': '0.7856645286083221'},
#   {'id': '1083_Barclays',
#    'snippet': 'barclays in $13.75 million us settlement over mutual funds',
#    'sentiment_scores': '0.7682791352272034'},
#   {'id': '1088_Tesco',
#    'snippet': 'tesco uk personnel director quits supermarket',
#    'sentiment_scores': '0.6739408075809479'},
#   {'id': '109_Severn Trent',
#    'snippet': 'companies severn trent expects costs hit from inflation',
#    'sentiment_scores': '0.758159726858139'},
#   {'id': '10_EasyJet',
#    'snippet': 'update 2-easyjet sees better first half on lower fuel bill',
#    'sentiment_scores': '0.7913378775119781'},
#   {'id': '1104_BHP Billiton',
#    'snippet': 'bhp billiton to lower copper production costs',
#    'sentiment_scores': '0.7807545065879822'},
#   {'id': '1115_AstraZeneca',
#    'snippet': 'astrazeneca in talks to buy cancer drug developer acerta pharma',
#    'sentiment_scores': '0.7710932493209839'},
#   {'id': '1123_Lloyds',
#    'snippet': 'osborne extends lloyds sell-off plan',
#    'sentiment_scores': '0.767011284828186'},
#   {'id': '1126_Barclays',
#    'snippet': "industry newsbarclays to 'cut investment bank staff by another 20%'",
#    'sentiment_scores': '0.7655993103981018'},
#   {'id': '1127_RBS',
#    'snippet': 'rbs investment bank to return to profit after overhaul, ceo says',
#    'sentiment_scores': '0.7596362829208374'},
#   {'id': '1138_Barclays',
#    'snippet': 'che banca! ceo says barclays buy to lift profit from 2016-17',
#    'sentiment_scores': '0.6300998628139496'},
#   {'id': '113_BHP',
#    'snippet': "bhp's iron ore outlook holds little cheer for small miners",
#    'sentiment_scores': '0.8162841796875'},
#   {'id': '1163_Morrisons',
#    'snippet': 'early victory for new ceo as morrisons beats forecasts',
#    'sentiment_scores': '0.7848729193210602'},
#   {'id': '1173_BP',
#    'snippet': 'bp to slash 4000 jobs globally as oil prices drop',
#    'sentiment_scores': '0.7936800420284271'},
#   {'id': '1175_Morrisons',
#    'snippet': 'uk supermarket group morrisons cuts fresh food prices',
#    'sentiment_scores': '0.7918222546577454'},
#   {'id': '117_AO World',
#    'snippet': 'ao world shares tumble on profit warning',
#    'sentiment_scores': '0.7886468172073364'},
#   {'id': '1187_Direct Line',
#    'snippet': 'direct line expects claims of â£110-140 million from three storms',
#    'sentiment_scores': '0.7988161742687225'},
#   {'id': '1188_RBS',
#    'snippet': 'rbs shares drop after surprise pension charge cuts capital',
#    'sentiment_scores': '0.766849935054779'},
#   {'id': '119_StanLife',
#    'snippet': 'stanlife leads ftse after strong earnings',
#    'sentiment_scores': '0.7729839384555817'},
#   {'id': '1214_Diageo',
#    'snippet': 'diageo offloads major wine interests',
#    'sentiment_scores': '0.776065468788147'},
#   {'id': '1235_Glencore',
#    'snippet': 'update 1-lpc-glencore launches refinancing of us$8.45bn loan',
#    'sentiment_scores': '0.7636446356773376'},
#   {'id': '1238_Glencore',
#    'snippet': 'lpc-glencore launches refinancing of $8.45billion loan',
#    'sentiment_scores': '0.7990529537200928'},
#   {'id': '124_RBS',
#    'snippet': 'rbs breaks with past by tearing investment bank apart',
#    'sentiment_scores': '0.7856013774871826'},
#   {'id': '1254_Smith & Nephew',
#    'snippet': 'smith & nephew 2015 trading profit beats expectations',
#    'sentiment_scores': '0.7710932493209839'},
#   {'id': '1263_BT Group',
#    'snippet': "bt group's third quarter revenues rise as restructure unveiled",
#    'sentiment_scores': '0.7712721824645996'},
#   {'id': '1266_Johnston Press',
#    'snippet': "indy future in doubt as johnston press lines up deal for 'i'",
#    'sentiment_scores': '0.7999955415725708'},
#   {'id': '1269_BP',
#    'snippet': 'bp shares tumble after $2.2bn fourth-quarter loss',
#    'sentiment_scores': '0.8305810987949371'},
#   {'id': '126_Randgold Resources',
#    'snippet': 'randgold resources q4 profit decreases - quick facts',
#    'sentiment_scores': '0.8039903938770294'},
#   {'id': '1271_BHP Billiton',
#    'snippet': 'bhp billiton says no settlement yet on brazil dam disaster',
#    'sentiment_scores': '0.7622141540050507'},
#   {'id': '1273_Hargreaves Landown',
#    'snippet': 'hargreaves landown slides on trading update',
#    'sentiment_scores': '0.8157137632369995'},
#   {'id': '1280_AstraZeneca',
#    'snippet': 'astrazeneca says new lung cancer pill tagrisso approved by eu',
#    'sentiment_scores': '0.8021918535232544'},
#   {'id': '1285_Berkshire Hathaway',
#    'snippet': "warren buffett's berkshire hathaway quarterly profit jumps almost one third",
#    'sentiment_scores': '0.7612750828266144'},
#   {'id': '1286_Genel',
#    'snippet': "genel shares plunge after tony hayward's oil explorer cuts crude reserves at core field",
#    'sentiment_scores': '0.7778536081314087'},
#   {'id': '1300_AstraZeneca',
#    'snippet': 'astrazeneca agrees licensing deal for plendil in china',
#    'sentiment_scores': '0.7642794847488403'},
#   {'id': '1301_Glencore',
#    'snippet': 'glencore posts 5.7 pct fall in q4 copper output',
#    'sentiment_scores': '0.8088445663452148'},
#   {'id': '1310_Glencore',
#    'snippet': 'glencore to refinance its short-term debt early, shares rise',
#    'sentiment_scores': '0.7211039066314697'},
#   {'id': '131_Glaxo',
#    'snippet': 'glaxo sees hope for respiratory drugs as earnings beat estimates',
#    'sentiment_scores': '0.8183616697788239'},
#   {'id': '1321_Weir Group',
#    'snippet': 'industry newsrevenue, earnings take a tumble at weir group',
#    'sentiment_scores': '0.7941662073135376'},
#   {'id': '1337_AstraZeneca',
#    'snippet': 'companiesastrazeneca shares hit as 2016 revenue forecast to fall',
#    'sentiment_scores': '0.7624065279960632'},
#   {'id': '1338_Lloyds Banking Group',
#    'snippet': 'lloyds banking group reports 7% dip in annual profits',
#    'sentiment_scores': '0.7635353207588196'},
#   {'id': '1340_Berkshire',
#    'snippet': "update 3-buffett's berkshire raises oil bet with kinder morgan stake",
#    'sentiment_scores': '0.7350505888462067'},
#   {'id': '1344_Associated British Foods',
#    'snippet': 'associated british foods raises guidance as sterling wilts',
#    'sentiment_scores': '0.7783256769180298'},
#   {'id': '1347_Glencore',
#    'snippet': 'companiesglencore shares hit 3-month high after refinancing key credit line',
#    'sentiment_scores': '0.7761662602424622'},
#   {'id': '1348_JP Morgan Chase',
#    'snippet': 'companiescoutts raids jpmorgan chase for new ceo',
#    'sentiment_scores': '0.7889807522296906'},
#   {'id': '1355_Admiral and Schroders',
#    'snippet': 'admiral and schroders lift ftse with profits surge',
#    'sentiment_scores': '0.8075015246868134'},
#   {'id': '1361_Admiral',
#    'snippet': "britain's ftse buoyed by admiral, building sector gains",
#    'sentiment_scores': '0.7906588017940521'},
#   {'id': '1363_Legal & General',
#    'snippet': "legal & general's capital update outweighs profit rise",
#    'sentiment_scores': '0.7789922952651978'},
#   {'id': '1369_Kingfisher',
#    'snippet': "britain's ftse advances as investors cheer kingfisher results",
#    'sentiment_scores': '0.7711178660392761'},
#   {'id': '1374_BP',
#    'snippet': 'bp ends 27-year sponsorship of tate as falling oil price takes toll',
#    'sentiment_scores': '0.8181224763393402'},
#   {'id': '1393_Shell',
#    'snippet': "shell ceo van beurden's remuneration fell in 2015",
#    'sentiment_scores': '0.806056946516037'},
#   {'id': '1397_HSBC',
#    'snippet': "hsbc money laundering report's release delayed amid us appeal",
#    'sentiment_scores': '0.7759038209915161'},
#   {'id': '1399_Rio Tinto',
#    'snippet': "standout performer' js jacques picked to lead rio tinto",
#    'sentiment_scores': '0.764262467622757'},
#   {'id': '1401_Barclays',
#    'snippet': 'barclays reports 8% fall in annual profits',
#    'sentiment_scores': '0.8067771792411804'},
#   {'id': '1406_Metro Bank',
#    'snippet': 'companiesmetro bank raises â£400m ahead of london listing',
#    'sentiment_scores': '0.7969304323196411'},
#   {'id': '1411_Sports Direct',
#    'snippet': 'sports direct boss mike ashley summoned to westminster for questioning over the treatment of workers',
#    'sentiment_scores': '0.7945253252983093'},
#   {'id': '1413_Aggreko',
#    'snippet': 'aggreko says first half profits will be lower as the oil price rout claims its latest victim',
#    'sentiment_scores': '0.7821817696094513'},
#   {'id': '141_Berkshire Hathaway',
#    'snippet': "berkshire hathaway's 4q profit declines 17 percent",
#    'sentiment_scores': '0.789560854434967'},
#   {'id': '144_Bunzl',
#    'snippet': 'bunzl delivers small profit increase for 2014',
#    'sentiment_scores': '0.745805561542511'},
#   {'id': '1452_BP',
#    'snippet': 'bp sees q1 earnings slide as low oil prices take their toll',
#    'sentiment_scores': '0.7928929626941681'},
#   {'id': '1457_BP',
#    'snippet': 'bp reports $583 million loss in first quarter',
#    'sentiment_scores': '0.7710859775543213'},
#   {'id': '1459_AB InBev',
#    'snippet': 'ab inbev offers to sell some sabmiller brands',
#    'sentiment_scores': '0.7899894714355469'},
#   {'id': '1464_AstraZeneca',
#    'snippet': 'astrazeneca to cut costs but stays silent on m&a talk',
#    'sentiment_scores': '0.7725235521793365'},
#   {'id': '1466_Barclays',
#    'snippet': 'barclays in talks with anacap to sell french consumer operations',
#    'sentiment_scores': '0.7956743538379669'},
#   {'id': '1479_Kraft Heinz',
#    'snippet': 'the latest: buffett says cuts will pay off at kraft heinz',
#    'sentiment_scores': '0.7893171012401581'},
#   {'id': '1483_Shoeders',
#    'snippet': 'schroders assets hit record in q1, buoyed by institutional inflows',
#    'sentiment_scores': '0.7703736424446106'},
#   {'id': '1489_Barclays',
#    'snippet': 'former barclays traders stand trial in libor case',
#    'sentiment_scores': '0.7682708501815796'},
#   {'id': '148_Standard Life',
#    'snippet': 'standard life impresses as fee-based products offset annuities slump',
#    'sentiment_scores': '0.7874532043933868'},
#   {'id': '1494_Sky',
#    'snippet': "britain's ftse slips from 2016 high as sky falls",
#    'sentiment_scores': '0.7649955749511719'},
#   {'id': '149_Reed Elsevier',
#    'snippet': 'reed elsevier shares cool after profit dip',
#    'sentiment_scores': '0.8002286553382874'},
#   {'id': '1520_Lloyds',
#    'snippet': 'retail focus helps to shield lloyds from banking chill',
#    'sentiment_scores': '0.7827198803424835'},
#   {'id': '1538_Centrica',
#    'snippet': 'companiescentrica shares drop 7% amid capital raise',
#    'sentiment_scores': '0.8058066964149475'},
#   {'id': '1539_United Utilities',
#    'snippet': 'united utilities fy profit up 3.5%; to boost capex',
#    'sentiment_scores': '0.7889807522296906'},
#   {'id': '1542_Compass',
#    'snippet': 'companiescompass serves up half year profit rise',
#    'sentiment_scores': '0.7720041275024414'},
#   {'id': '1547_SABMiller',
#    'snippet': 'currency causes full-year headaches for sabmiller',
#    'sentiment_scores': '0.7728475034236908'},
#   {'id': '1572_Exxon',
#    'snippet': 'exxon beaumont cdu overhaul to be slowed by accident: sources',
#    'sentiment_scores': '0.7782467305660248'},
#   {'id': '1574_G4S',
#    'snippet': "companiesg4s claims 'positive' start to the year",
#    'sentiment_scores': '0.7271203696727753'},
#   {'id': '1594_Rio Tinto',
#    'snippet': 'rio tinto announces long-delayed expansion of mongolia mine',
#    'sentiment_scores': '0.7811081409454346'},
#   {'id': '1603_Apple',
#    'snippet': "warren buffett's berkshire hathaway buys stake in apple",
#    'sentiment_scores': '0.7753035426139832'},
#   {'id': '1614_Royal Mail',
#    'snippet': 'ofcom says will not impose new price controls on royal mail',
#    'sentiment_scores': '0.7533820271492004'}]}
